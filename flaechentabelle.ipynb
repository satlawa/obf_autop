# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import docx

from docx import Document
from docx.oxml import OxmlElement
from docx.oxml.ns import qn
from docx.shared import Cm
from docx.shared import Pt

from docx.enum.section import WD_ORIENT
from docx.enum.section import WD_SECTION

# %%
# set home directory
home_path = os.getcwd()[:os.getcwd().find('Code/obf_autop')-1]
# set data_path
data_path = os.path.join(home_path, 'Data', 'obf_autop', 'TO1356', 'to_1356_sap.XLS')

# %%
data_path = os.path.join(home_path, 'Data', 'obf_autop')
data_path
# Out:
# '/Users/philipp/Data/obf_autop'

# %%
from OBFFlTab import OBFFlTab

# set Teiloperats-ID
to_now = '1356' # 1343, 1341, 1345, 1353, 1354, 1355, 1356, 1361

# run program
obf_main = OBFFlTab(data_path, to_now)
# Out:
# -----------------------------------------------------
# -                                                   -
# -                   files exist                     -
# -                                                   -
# -----------------------------------------------------
# SAP Rohdaten:       to_1356_sap.XLS:             True
# -----------------------------------------------------
# Zusatz Dateien:     dict:                        True
# -----------------------------------------------------

# %%
obf_main.run()
# Out:
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3191: DtypeWarning: Columns (147,148,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# ***   0 Deckblatt   ***
# ***   1 Abkürzungsverzeichnis   ***
# ***   2 Flächentabellen   ***
# 506
# 507
# 508
# 525
# 526
# 527
# 24
# 25
# 26
# 54
# 55
# 56
# 39
# 40
# 41
# end
# successfully made in /Users/philipp/Data/obf_autop

# %%
data_path
# Out:
# '/Users/philipp/Data/obf_autop'

# %%
from OBFFlaechentabelle import OBFFlaechentabelle
data_path = os.path.join(home_path, 'Data', 'obf_autop', 'TO1356', 'to_1356_sap.XLS')
obf_flt = OBFFlaechentabelle(pd.read_csv(data_path, sep='\t', encoding = "ISO-8859-1", decimal=',', error_bad_lines=False))
# Out:
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (147,148,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_raw = pd.read_csv(data_path, sep='\t', encoding = "ISO-8859-1", decimal=',', error_bad_lines=False)
# Out:
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (147,148,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from OBFFlaechentabelle import OBFFlaechentabelle
flt = OBFFlaechentabelle(data_raw)

# %%
print(flt.fr)
print(flt.fr_abt[0])
# Out:
# [1 2 3 4 5]
# [506 507 508 509 510 511 512 513 514 515 516 517 518 519 520 521 522 523
#  524 533 534 535 536 537 538 595 596 597 598 599 648 649 650 651 652 653
#  654 655 656 657 658 659 664 700 701 702 703 704 705 706 707 708 709 710
#  711 712 713 714 715 716 717 718 719 720 721 722 723 724 725 726 727 728
#  729 730 731 732 733 734 735 736 737 738 739 740]

# %%
x = flt.create_table(1,510)
x
# Out:
#        Abt UAbt Tfl WE Typ   BKL   UZ EtrS BW Typ SW Typ NG Typ  Fl WW Fl SW  \
# 945    510    A   1     WO  9060  120    I      W      -      -    5.6     -
# 874    510    A   2     WO  9010  120    I      W      -      -   4.03     -
# 783    510    A   3     WO  9010  120    I      W      -      -   1.53     -
# 1175   510    B   1     WO  9010  120    I      W      -      -   8.76     -
# 1191   510    B   2     WO  9010  140    I      W      -      -   1.38     -
# 1207   510    B   3     WO  9010  140    I      W      -      -   1.44     -
# 1242   510    B   4     WO  9010  140    I      W      -      -   1.69     -
# 1212   510    C   1     WO  9010  140    I      W      -      -   0.59     -
# 1195   510    C   2     WO  9010  140    I      W      -      -    1.2     -
# 1181   510    C   3     WO  9010  140    I      W      -      -   3.16     -
# 1134   510    C   4     WO  9010  140    I      W      -      -   1.71     -
# 1094   510    D   0     WO  9010  140    I      W      -      -   3.08     -
# 2113   510    3   1     NG     -    0    -      -      -      3      -     -
# 2018   510    7   1     NG     -    0    -      -      -      7      -     -
# Ges.  Ges.    -   -      -     -    -    -      -      -      -  34.17     0
#
#      Fl NHB Fl pNG Fl uNG  Fl Ges
# 945       -      -      -    5.60
# 874       -      -      -    4.03
# 783       -      -      -    1.53
# 1175      -      -      -    8.76
# 1191      -      -      -    1.38
# 1207      -      -      -    1.44
# 1242      -      -      -    1.69
# 1212      -      -      -    0.59
# 1195      -      -      -    1.20
# 1181      -      -      -    3.16
# 1134      -      -      -    1.71
# 1094      -      -      -    3.08
# 2113   2.29      -      -    2.29
# 2018      -      -   0.03    0.03
# Ges.   2.29      0   0.03   36.49

# %%
x.dtypes
# Out:
# Abt        object
# UAbt       object
# Tfl        object
# WE Typ     object
# BKL        object
# UZ         object
# EtrS       object
# BW Typ     object
# SW Typ     object
# NG Typ     object
# Fl WW      object
# Fl SW      object
# Fl NHB     object
# Fl pNG     object
# Fl uNG     object
# Fl Ges    float64
# dtype: object

# %%
x.describe
# Out:
# <bound method NDFrame.describe of       Abt  UAbt Tfl WE Typ   BKL   UZ EtrS BW Typ SW Typ NG Typ Fläche WW  \
# 945   510     A   1     WO  9060  120    I      W      -      -       5.6
# 874   510     A   2     WO  9010  120    I      W      -      -      4.03
# 783   510     A   3     WO  9010  120    I      W      -      -      1.53
# 1175  510     B   1     WO  9010  120    I      W      -      -      8.76
# 1191  510     B   2     WO  9010  140    I      W      -      -      1.38
# 1207  510     B   3     WO  9010  140    I      W      -      -      1.44
# 1242  510     B   4     WO  9010  140    I      W      -      -      1.69
# 1212  510     C   1     WO  9010  140    I      W      -      -      0.59
# 1195  510     C   2     WO  9010  140    I      W      -      -       1.2
# 1181  510     C   3     WO  9010  140    I      W      -      -      3.16
# 1134  510     C   4     WO  9010  140    I      W      -      -      1.71
# 1094  510     D   0     WO  9010  140    I      W      -      -      3.08
# 2113  510     3   1     NG     -    0    -      -      -      3         -
# 2018  510     7   1     NG     -    0    -      -      -      7         -
# Ges.  510  Ges.   -      -     -    -    -      -      -      -     34.17
#
#      Fläche SW Fläche NHB Fläche pNG Fläche uNG  Fläche Ges
# 945          -          -          -          -        5.60
# 874          -          -          -          -        4.03
# 783          -          -          -          -        1.53
# 1175         -          -          -          -        8.76
# 1191         -          -          -          -        1.38
# 1207         -          -          -          -        1.44
# 1242         -          -          -          -        1.69
# 1212         -          -          -          -        0.59
# 1195         -          -          -          -        1.20
# 1181         -          -          -          -        3.16
# 1134         -          -          -          -        1.71
# 1094         -          -          -          -        3.08
# 2113         -       2.29          -          -        2.29
# 2018         -          -          -       0.03        0.03
# Ges.         0       2.29          0       0.03       36.49  >

# %%
x = x.astype(str)

# %%
x
# Out:
#       Abt  UAbt  Tfl WE Typ     BKL     UZ EtrS BW Typ SW Typ NG Typ  \
# 945   510     A  1.0     WO  9060.0  120.0    I      W      -      -
# 874   510     A  2.0     WO  9010.0  120.0    I      W      -      -
# 783   510     A  3.0     WO  9010.0  120.0    I      W      -      -
# 1175  510     B  1.0     WO  9010.0  120.0    I      W      -      -
# 1191  510     B  2.0     WO  9010.0  140.0    I      W      -      -
# 1207  510     B  3.0     WO  9010.0  140.0    I      W      -      -
# 1242  510     B  4.0     WO  9010.0  140.0    I      W      -      -
# 1212  510     C  1.0     WO  9010.0  140.0    I      W      -      -
# 1195  510     C  2.0     WO  9010.0  140.0    I      W      -      -
# 1181  510     C  3.0     WO  9010.0  140.0    I      W      -      -
# 1134  510     C  4.0     WO  9010.0  140.0    I      W      -      -
# 1094  510     D  0.0     WO  9010.0  140.0    I      W      -      -
# 2113  510     3  1.0     NG       -    0.0    -      -      -    3.0
# 2018  510     7  1.0     NG       -    0.0    -      -      -    7.0
# Ges.  510  Ges.    -      -       -      -    -      -      -      -
#
#      Fläche WW Fläche SW Fläche NHB Fläche pNG Fläche uNG Fläche Ges
# 945        5.6         -          -          -          -        5.6
# 874       4.03         -          -          -          -       4.03
# 783       1.53         -          -          -          -       1.53
# 1175      8.76         -          -          -          -       8.76
# 1191      1.38         -          -          -          -       1.38
# 1207      1.44         -          -          -          -       1.44
# 1242      1.69         -          -          -          -       1.69
# 1212      0.59         -          -          -          -       0.59
# 1195       1.2         -          -          -          -        1.2
# 1181      3.16         -          -          -          -       3.16
# 1134      1.71         -          -          -          -       1.71
# 1094      3.08         -          -          -          -       3.08
# 2113         -         -       2.29          -          -       2.29
# 2018         -         -          -          -       0.03       0.03
# Ges.     34.17       0.0       2.29        0.0       0.03      36.49

# %%
x['Tfl']
# Out:
# 945     1.0
# 874     2.0
# 783     3.0
# 1175    1.0
# 1191    2.0
# 1207    3.0
# 1242    4.0
# 1212    1.0
# 1195    2.0
# 1181    3.0
# 1134    4.0
# 1094    0.0
# 2113    1.0
# Name: Tfl, dtype: object

# %%
# Flaeche der WO (2.1)
data_wo_fl = data_raw[data_raw['Schichtalter'] == 0]

# %%
data_wo_fl.head()
# Out:
#    Merkmalausprägung  AuswKatTyp  Teiloperats-ID  Forstbetrieb  Debitor  \
# 0                  0         NaN            1356           171   220442
# 1                  0         NaN            1356           171   220442
# 2                  0         NaN            1356           171   220442
# 3                  0         NaN            1356           171   220442
# 4                  0         NaN            1356           171   220442
#
#   TO-Bezeichnung  Status Beg. Laufzeit Ende Laufzeit  Operat-ID      ...       \
# 0        FE 2019       2    01.01.2020    31.12.2029        291      ...
# 1        FE 2019       2    01.01.2020    31.12.2029        291      ...
# 2        FE 2019       2    01.01.2020    31.12.2029        291      ...
# 3        FE 2019       2    01.01.2020    31.12.2029        291      ...
# 4        FE 2019       2    01.01.2020    31.12.2029        291      ...
#
#    Zeile1 Zeile2 Zeile3  Zeile4 Zeile5  Zeile6  Zeile7  Zeile8  \
# 0     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 1     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 2     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 3     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
# 4     NaN    NaN    NaN     NaN    NaN     NaN     NaN     NaN
#
#    Bestockungsziel Flächenanteil
# 0              NaN           0.0
# 1              NaN           0.0
# 2              NaN           0.0
# 3              NaN           0.0
# 4              NaN           0.0
#
# [5 rows x 152 columns]

# %%
data_wo_fl.columns[:100]
# Out:
# Index(['Merkmalausprägung', 'AuswKatTyp', 'Teiloperats-ID', 'Forstbetrieb',
#        'Debitor', 'TO-Bezeichnung', 'Status', 'Beg. Laufzeit', 'Ende Laufzeit',
#        'Operat-ID', 'vorgeschl. Hiebssatz', 'Verantwortlicher',
#        'Erfassungsstatus', 'Migriert?', 'GUID', 'Forstbetrieb.1',
#        'Teiloperats-ID.1', 'Forstrevier', 'Abteilung', 'Unterabteil.',
#        'Teilfl.', 'Debitor.1', 'Bearbeitungsblock', 'WE-Typ', 'Betriebsklasse',
#        'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation',
#        'Bewirtschaftungsform', 'Schutzwaldkategorie', 'Fläche in HA',
#        'Seehöhe', 'Exposition', 'Neigung', 'Standorteinheit', 'Vegetationstyp',
#        'Waldtyp', 'Wuchsgebiet', 'Überh. Laubholz', 'Überh. Nadelhz.',
#        'fr. Schälschade', 'Verbissgrad', 'SchutzwaldProjNr', 'Schlussgrad',
#        'Stabilität', 'VJ Bedingung', 'VJ Situation', 'Erreichbark. des BZ',
#        'Selektiver Verbiss', 'Erfassungsstatus.1', 'Storno', 'Angelegt von',
#        'Angelegt am', 'Uhrzeit', 'Geändert von', 'Geändert am', 'Uhrzeit.1',
#        'Waldort', 'GUID.1', 'GUID.2', 'Forstbetrieb.2', 'Teiloperats-ID.2',
#        'Forstrevier.1', 'Abteilung.1', 'Unterabteil..1', 'Teilfl..1',
#        'Best.-Schicht', 'Debitor.2', 'Schichtanteil', 'Schichtalter',
#        'S-Best.grad', 'Erfassungsstatus.2', 'Storno.1', 'GUID.3', 'GUID.4',
#        'Forstbetrieb.3', 'Teiloperats-ID.3', 'Forstrevier.2', 'Abteilung.2',
#        'Unterabteil..2', 'Teilfl..2', 'Best.-Schicht.1', 'Baumart',
#        'Debitor.3', 'Baumartenanteil', 'BaumartenBestockgrad', 'Schälgrad',
#        'Ertragsklasse', 'Vorrat / ha', 'Laubholzvorrat / ha',
#        'Nadelholzvorrat / ha', 'Vorrat am Ort', 'Laubholzvorrat Ort',
#        'Nadelholzvorrat Ort', 'GSOLL / HA', 'GIST / HA', 'lauf. Zuwachs / HA',
#        'DGZU / HA', 'HDZ', 'LGZ'],
#       dtype='object')

# %%
data_wo_fl = data_wo_fl[['Forstrevier','Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse',
       'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation',
       'Bewirtschaftungsform', 'Schutzwaldkategorie', 'Fläche in HA']]

# %%
# get Forstreviere 
fr = np.sort(data_wo_fl['Forstrevier'].unique())
print(fr)
# Out:
# [1 2 3 4 5]

# %%
# get Abteilungen for every Forstrevier
fr_abt = []
for f in fr:
    fr_abt.append(np.sort(data_wo_fl.loc[data_wo_fl['Forstrevier']==f,'Abteilung'].unique()))

# %%
fr_abt[0]
# Out:
# array([506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518,
#        519, 520, 521, 522, 523, 524, 533, 534, 535, 536, 537, 538, 595,
#        596, 597, 598, 599, 648, 649, 650, 651, 652, 653, 654, 655, 656,
#        657, 658, 659, 664, 700, 701, 702, 703, 704, 705, 706, 707, 708,
#        709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721,
#        722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734,
#        735, 736, 737, 738, 739, 740])

# %%
def create_table(fr, abt):

    # filter one Abteilung
    table = data_wo_fl.loc[(data_wo_fl['Forstrevier']==fr) & (data_wo_fl['Abteilung']==abt)]
    # sort table by WE-Typ , unterabteil. , Teilfl.
    table = table.sort_values(['Abteilung', 'WE-Typ', 'Unterabteil.', 'Teilfl.'], ascending=[True, False, True, True])
        
    table['fl_ww'] = table.loc[(table['Bewirtschaftungsform']=='W'),'Fläche in HA']
    table['fl_sw'] = table.loc[(table['Bewirtschaftungsform']=='S'),'Fläche in HA']
    table['fl_nhb'] = table.loc[(table['Nebengrund Art']==3) | (table['Nebengrund Art']==4),'Fläche in HA']
    table['fl_ngp'] = table.loc[(table['Nebengrund Art']==5) | (table['Nebengrund Art']==6),'Fläche in HA']
    table['fl_ngu'] = table.loc[(table['Nebengrund Art']<3) | (table['Nebengrund Art']>6),'Fläche in HA']

    sum_fl = {'Abteilung': 'Ges.', \
        'Fläche in HA': table['Fläche in HA'].sum(), 'fl_ww': table['fl_ww'].sum(), \
        'fl_sw': table['fl_sw'].sum(), 'fl_nhb': table['fl_nhb'].sum(), \
        'fl_ngp': table['fl_ngp'].sum(), 'fl_ngu': table['fl_ngu'].sum()}
    
    table = table.fillna('-')
    table[['Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse', 'Umtriebszeit', 'Nebengrund Art']] = \
    table[['Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse', 'Umtriebszeit', 'Nebengrund Art']].astype(str)
    
    table['Betriebsklasse'] = table['Betriebsklasse'].str.replace('.0', '', regex=False)
    table['Nebengrund Art'] = table['Nebengrund Art'].str.replace('.0', '', regex=False)

    sum_df = pd.DataFrame(data=sum_fl, index = ["Ges."])
    table = table.append(sum_df, sort=False)
    table.columns = ['FR', 'Abt', 'UAbt', 'Tfl', 'WE Typ', 'BKL', 'UZ', 'NG Typ', 'EtrS', \
    'BW Typ', 'SW Typ', 'Fl Ges', 'Fl WW', 'Fl SW', 'Fl NHB', 'Fl pNG', 'Fl uNG']
    table = table.reindex(columns= ['Abt', 'UAbt', 'Tfl', 'WE Typ', 'BKL', 'UZ', 'EtrS', \
    'BW Typ', 'SW Typ', 'NG Typ', 'Fl WW', 'Fl SW', 'Fl NHB', 'Fl pNG', 'Fl uNG', 'Fl Ges'])

    table = table.round(2)
    
    table = table.fillna('-')
    #table = table.astype(str)

    return table

# %%
print(create_table(1, 506))
# Out:
#        Abt UAbt Tfl WE Typ   BKL   UZ EtrS BW Typ SW Typ NG Typ  Fl WW Fl SW  \
# 804    506    A   0     WO  9010  140    I      W      -      -   8.69     -
# 994    506    B   1     WO  9010  140    I      W      -      -   0.81     -
# 959    506    B   2     WO  9010  140    I      W      -      -   0.63     -
# 955    506    C   1     WO  9010  140    I      W      -      -   3.24     -
# 928    506    C   2     WO  9010  140    I      W      -      -   2.93     -
# 906    506    D   1     WO  9010  140    I      W      -      -   1.96     -
# 885    506    D   2     WO  9010  140    I      W      -      -   1.14     -
# 859    506    D   3     WO  9010  140    I      W      -      -   1.42     -
# 843    506    D   4     WO  9010  140    I      W      -      -   1.39     -
# 963    506    E   1     WO  9050  160    I      W      -      -   2.88     -
# 933    506    E   2     WO  9010  140    I      W      -      -   0.92     -
# 909    506    F   1     WO  9050  160    I      W      -      -   3.45     -
# 882    506    F   2     WO  9010  140    I      W      -      -   1.27     -
# 849    506    G   1     WO  9010  140    I      W      -      -   1.98     -
# 830    506    G   2     WO  9010  140    I      W      -      -   0.37     -
# 718    506    3   1     NG     -    0    -      -      -      3      -     -
# 714    506    5   1     NG     -    0    -      -      -      5      -     -
# 710    506    9   1     NG     -    0    -      -      -      9      -     -
# 4512   506    9   2     NG     -    0    -      -      -      9      -     -
# Ges.  Ges.    -   -      -     -    -    -      -      -      -  33.08     0
#
#      Fl NHB Fl pNG Fl uNG  Fl Ges
# 804       -      -      -    8.69
# 994       -      -      -    0.81
# 959       -      -      -    0.63
# 955       -      -      -    3.24
# 928       -      -      -    2.93
# 906       -      -      -    1.96
# 885       -      -      -    1.14
# 859       -      -      -    1.42
# 843       -      -      -    1.39
# 963       -      -      -    2.88
# 933       -      -      -    0.92
# 909       -      -      -    3.45
# 882       -      -      -    1.27
# 849       -      -      -    1.98
# 830       -      -      -    0.37
# 718    2.03      -      -    2.03
# 714       -   0.09      -    0.09
# 710       -      -   0.24    0.24
# 4512      -      -   0.38    0.38
# Ges.   2.03   0.09   0.62   35.82

# %%
x = create_table(1, 506)

# %%
x['Abt'].astype(str)
# Out:
# 804      506.0
# 994      506.0
# 959      506.0
# 955      506.0
# 928      506.0
# 906      506.0
# 885      506.0
# 859      506.0
# 843      506.0
# 963      506.0
# 933      506.0
# 909      506.0
# 882      506.0
# 849      506.0
# 830      506.0
# 718      506.0
# 714      506.0
# 710      506.0
# 4512     506.0
# Total      nan
# Name: Abt, dtype: object

# %%
# filter one Abteilung
x = data_wo_fl.loc[(data_wo_fl['Forstrevier']==1) & (data_wo_fl['Abteilung']==506)]
# sort WE-Typ , unterabteil. , Teilfl.
x = x.sort_values(['Abteilung', 'WE-Typ', 'Unterabteil.', 'Teilfl.'], ascending=[True, False, True, True])

# %%
x
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 804             1        506            A        0     WO          9010.0
# 994             1        506            B        1     WO          9010.0
# 959             1        506            B        2     WO          9010.0
# 955             1        506            C        1     WO          9010.0
# 928             1        506            C        2     WO          9010.0
# 906             1        506            D        1     WO          9010.0
# 885             1        506            D        2     WO          9010.0
# 859             1        506            D        3     WO          9010.0
# 843             1        506            D        4     WO          9010.0
# 963             1        506            E        1     WO          9050.0
# 933             1        506            E        2     WO          9010.0
# 909             1        506            F        1     WO          9050.0
# 882             1        506            F        2     WO          9010.0
# 849             1        506            G        1     WO          9010.0
# 830             1        506            G        2     WO          9010.0
# 718             1        506            3        1     NG             NaN
# 714             1        506            5        1     NG             NaN
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 804            140             NaN                I                    W
# 994            140             NaN                I                    W
# 959            140             NaN                I                    W
# 955            140             NaN                I                    W
# 928            140             NaN                I                    W
# 906            140             NaN                I                    W
# 885            140             NaN                I                    W
# 859            140             NaN                I                    W
# 843            140             NaN                I                    W
# 963            160             NaN                I                    W
# 933            140             NaN                I                    W
# 909            160             NaN                I                    W
# 882            140             NaN                I                    W
# 849            140             NaN                I                    W
# 830            140             NaN                I                    W
# 718              0             3.0              NaN                  NaN
# 714              0             5.0              NaN                  NaN
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  Fläche in HA
# 804                   NaN          8.69
# 994                   NaN          0.81
# 959                   NaN          0.63
# 955                   NaN          3.24
# 928                   NaN          2.93
# 906                   NaN          1.96
# 885                   NaN          1.14
# 859                   NaN          1.42
# 843                   NaN          1.39
# 963                   NaN          2.88
# 933                   NaN          0.92
# 909                   NaN          3.45
# 882                   NaN          1.27
# 849                   NaN          1.98
# 830                   NaN          0.37
# 718                   NaN          2.03
# 714                   NaN          0.09
# 710                   NaN          0.24
# 4512                  NaN          0.38

# %%
x[x['Nebengrund Art']==3.0]
# Out:
#      Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 718            1        506            3        1     NG             NaN
#
#      Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 718             0             3.0              NaN                  NaN
#
#      Schutzwaldkategorie  Fläche in HA
# 718                  NaN          2.03

# %%
x[x['Nebengrund Art']==9.0]
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  Fläche in HA
# 710                   NaN          0.24
# 4512                  NaN          0.38

# %%
x.loc[(x['Nebengrund Art']==3.0),'Fläche in HA']
# Out:
# 718    2.03
# Name: Fläche in HA, dtype: float64

# %%
x['fl_ww'] = x.loc[(x['Bewirtschaftungsform']=='W'),'Fläche in HA']
x['fl_sw'] = x.loc[(x['Bewirtschaftungsform']=='S'),'Fläche in HA']
x['fl_nh'] = x.loc[(x['Nebengrund Art']==3.0),'Fläche in HA']
x['fl_rest'] = x.loc[(x['Nebengrund Art']==9.0),'Fläche in HA']

# %%
x
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 804             1        506            A        0     WO          9010.0
# 994             1        506            B        1     WO          9010.0
# 959             1        506            B        2     WO          9010.0
# 955             1        506            C        1     WO          9010.0
# 928             1        506            C        2     WO          9010.0
# 906             1        506            D        1     WO          9010.0
# 885             1        506            D        2     WO          9010.0
# 859             1        506            D        3     WO          9010.0
# 843             1        506            D        4     WO          9010.0
# 963             1        506            E        1     WO          9050.0
# 933             1        506            E        2     WO          9010.0
# 909             1        506            F        1     WO          9050.0
# 882             1        506            F        2     WO          9010.0
# 849             1        506            G        1     WO          9010.0
# 830             1        506            G        2     WO          9010.0
# 718             1        506            3        1     NG             NaN
# 714             1        506            5        1     NG             NaN
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 804            140             NaN                I                    W
# 994            140             NaN                I                    W
# 959            140             NaN                I                    W
# 955            140             NaN                I                    W
# 928            140             NaN                I                    W
# 906            140             NaN                I                    W
# 885            140             NaN                I                    W
# 859            140             NaN                I                    W
# 843            140             NaN                I                    W
# 963            160             NaN                I                    W
# 933            140             NaN                I                    W
# 909            160             NaN                I                    W
# 882            140             NaN                I                    W
# 849            140             NaN                I                    W
# 830            140             NaN                I                    W
# 718              0             3.0              NaN                  NaN
# 714              0             5.0              NaN                  NaN
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  Fläche in HA  fl_ww  fl_sw  fl_nh  fl_rest
# 804                   NaN          8.69   8.69    NaN    NaN      NaN
# 994                   NaN          0.81   0.81    NaN    NaN      NaN
# 959                   NaN          0.63   0.63    NaN    NaN      NaN
# 955                   NaN          3.24   3.24    NaN    NaN      NaN
# 928                   NaN          2.93   2.93    NaN    NaN      NaN
# 906                   NaN          1.96   1.96    NaN    NaN      NaN
# 885                   NaN          1.14   1.14    NaN    NaN      NaN
# 859                   NaN          1.42   1.42    NaN    NaN      NaN
# 843                   NaN          1.39   1.39    NaN    NaN      NaN
# 963                   NaN          2.88   2.88    NaN    NaN      NaN
# 933                   NaN          0.92   0.92    NaN    NaN      NaN
# 909                   NaN          3.45   3.45    NaN    NaN      NaN
# 882                   NaN          1.27   1.27    NaN    NaN      NaN
# 849                   NaN          1.98   1.98    NaN    NaN      NaN
# 830                   NaN          0.37   0.37    NaN    NaN      NaN
# 718                   NaN          2.03    NaN    NaN   2.03      NaN
# 714                   NaN          0.09    NaN    NaN    NaN      NaN
# 710                   NaN          0.24    NaN    NaN    NaN     0.24
# 4512                  NaN          0.38    NaN    NaN    NaN     0.38

# %%
x['fl_ww'].sum()
# Out:
# 33.080000000000005

# %%
xx = x.copy()

# %%
xx.loc['Total'] = pd.Series(xx['fl_ww'].sum(), index = ['fl_ww'])
xx.loc['Total'] = pd.Series(xx['fl_sw'].sum(), index = ['fl_sw'])
xx.loc['Total'] = pd.Series(xx['fl_nh'].sum(), index = ['fl_nh'])
xx.loc['Total'] = pd.Series(xx['fl_rest'].sum(), index = ['fl_rest'])

# %%
sum_df = {'fl_ww': xx['fl_ww'].sum(), 'fl_sw': xx['fl_sw'].sum(), 'fl_nh': xx['fl_nh'].sum(), 'fl_rest': xx['fl_rest'].sum()}

# %%
sum_df
# Out:
# {'fl_ww': 33.080000000000005, 'fl_sw': 0.0, 'fl_nh': 2.03, 'fl_rest': 0.62}

# %%
df = pd.DataFrame(data=sum_df, index = ["Total"])
df
# Out:
#        fl_ww  fl_sw  fl_nh  fl_rest
# Total  33.08    0.0   2.03     0.62

# %%
xx = xx.append(df)

# %%
xx
# Out:
#        Abteilung  Betriebsklasse Bewirtschaftungsform Ertragssituation  \
# 710        506.0             NaN                  NaN              NaN
# 714        506.0             NaN                  NaN              NaN
# 718        506.0             NaN                  NaN              NaN
# 804        506.0          9010.0                    W                I
# 830        506.0          9010.0                    W                I
# 843        506.0          9010.0                    W                I
# 849        506.0          9010.0                    W                I
# 859        506.0          9010.0                    W                I
# 882        506.0          9010.0                    W                I
# 885        506.0          9010.0                    W                I
# 906        506.0          9010.0                    W                I
# 909        506.0          9050.0                    W                I
# 928        506.0          9010.0                    W                I
# 933        506.0          9010.0                    W                I
# 955        506.0          9010.0                    W                I
# 959        506.0          9010.0                    W                I
# 963        506.0          9050.0                    W                I
# 994        506.0          9010.0                    W                I
# 4512       506.0             NaN                  NaN              NaN
# Total        NaN             NaN                  NaN              NaN
#
#        Fläche in HA  Forstrevier  Nebengrund Art  Schutzwaldkategorie  \
# 710            0.24          1.0             9.0                  NaN
# 714            0.09          1.0             5.0                  NaN
# 718            2.03          1.0             3.0                  NaN
# 804            8.69          1.0             NaN                  NaN
# 830            0.37          1.0             NaN                  NaN
# 843            1.39          1.0             NaN                  NaN
# 849            1.98          1.0             NaN                  NaN
# 859            1.42          1.0             NaN                  NaN
# 882            1.27          1.0             NaN                  NaN
# 885            1.14          1.0             NaN                  NaN
# 906            1.96          1.0             NaN                  NaN
# 909            3.45          1.0             NaN                  NaN
# 928            2.93          1.0             NaN                  NaN
# 933            0.92          1.0             NaN                  NaN
# 955            3.24          1.0             NaN                  NaN
# 959            0.63          1.0             NaN                  NaN
# 963            2.88          1.0             NaN                  NaN
# 994            0.81          1.0             NaN                  NaN
# 4512           0.38          1.0             9.0                  NaN
# Total           NaN          NaN             NaN                  NaN
#
#        Teilfl.  Umtriebszeit Unterabteil. WE-Typ  fl_nh  fl_rest  fl_sw  fl_ww
# 710        1.0           0.0            9     NG    NaN     0.24    NaN    NaN
# 714        1.0           0.0            5     NG    NaN      NaN    NaN    NaN
# 718        1.0           0.0            3     NG   2.03      NaN    NaN    NaN
# 804        0.0         140.0            A     WO    NaN      NaN    NaN   8.69
# 830        2.0         140.0            G     WO    NaN      NaN    NaN   0.37
# 843        4.0         140.0            D     WO    NaN      NaN    NaN   1.39
# 849        1.0         140.0            G     WO    NaN      NaN    NaN   1.98
# 859        3.0         140.0            D     WO    NaN      NaN    NaN   1.42
# 882        2.0         140.0            F     WO    NaN      NaN    NaN   1.27
# 885        2.0         140.0            D     WO    NaN      NaN    NaN   1.14
# 906        1.0         140.0            D     WO    NaN      NaN    NaN   1.96
# 909        1.0         160.0            F     WO    NaN      NaN    NaN   3.45
# 928        2.0         140.0            C     WO    NaN      NaN    NaN   2.93
# 933        2.0         140.0            E     WO    NaN      NaN    NaN   0.92
# 955        1.0         140.0            C     WO    NaN      NaN    NaN   3.24
# 959        2.0         140.0            B     WO    NaN      NaN    NaN   0.63
# 963        1.0         160.0            E     WO    NaN      NaN    NaN   2.88
# 994        1.0         140.0            B     WO    NaN      NaN    NaN   0.81
# 4512       2.0           0.0            9     NG    NaN     0.38    NaN    NaN
# Total      NaN           NaN          NaN    NaN   2.03     0.62    0.0  33.08

# %%
x = xx.copy()

# %%
x = x[['Forstrevier', 'Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse', 'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation', 'Bewirtschaftungsform', 'Schutzwaldkategorie', 'fl_ww', 'fl_sw', 'fl_nh', 'fl_rest']]
x = x.sort_values(['Abteilung', 'WE-Typ', 'Unterabteil.', 'Teilfl.'], ascending=[True, False, True, True])

# %%
x.columns = ['FR', 'Abt', 'Uabt', 'Tfl', 'WE-Typ',
       'BKL', 'UZ', 'NG Typ', 'Et sit',
       'BW Typ', 'SW Typ', 'fl_ww', 'fl_sw',
       'fl_nh', 'fl_rest']

# %%
x = x.fillna('-')

# %%
# make

# %%
from OBFDocX import OBFDocX
from OBFFlaechentabelle import OBFFlaechentabelle
from docx.shared import Pt

# set home directory
#home_path = os.getcwd()[:os.getcwd().find('Code/obf_autop')-1]
# set data_path
temp_path = os.path.join(os.getcwd(), 'data')
temp_path

flt = OBFFlaechentabelle(data_raw)

# %%
obf_doc = OBFDocX(Document(temp_path + '/templet_xx.docx'))

version = '0.8'

#######################
###   0 Deckblatt   ###
#######################
print('***   0 Deckblatt   ***')

obf_doc.doc.add_picture(temp_path + '/oebf.png')

for i in range(4):
    obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Flächentabelle zum OPERAT')
p.bold = True
p.font.name = 'Verdana'
p.font.size = Pt(34)

p = obf_doc.doc.add_paragraph().add_run('FB ') #+ str(obf_fuc.dic.fb) + ' ' + obf_fuc.dic.dic_num_fb[obf_fuc.dic.fb])
p.bold = True
p.font.name = 'Verdana'
p.font.size = Pt(35)

obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Teiloperat ') #+ str(obf_fuc.dic.to))
p.font.name = 'Verdana'
p.font.size = Pt(25)

for i in range(3):
    obf_doc.doc.add_paragraph('')

for i in ['Pernitz', 'Haselbach', 'Hinterbrühl']:

    p = obf_doc.doc.add_paragraph().add_run(i)
    p.font.name = 'Verdana'
    p.font.size = Pt(20)

#for i in range(12-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
#    p = obf_doc.doc.add_paragraph().add_run('')
#    p.font.size = Pt(20)

p = obf_doc.doc.add_paragraph().add_run('Organisationsstand 01.01.' + i)
p.font.name = 'Verdana'
p.font.size = Pt(18)

p = obf_doc.doc.add_paragraph().add_run('Laufzeit 01.01. - 31.12.')
p.font.name = 'Verdana'
p.font.size = Pt(18)

#for i in range(10-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
#    obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Für die Unternehmensleitung                       Für der Forstbetrieb')
p.font.name = 'Verdana'
p.font.size = Pt(12)

obf_doc.doc.add_page_break()

#############################
###   1 Abkürzungsverzeichnis   ###
#############################

for i in range(3):
    obf_doc.doc.add_paragraph('')

run = obf_doc.doc.add_paragraph('Erstellung vom Teiloperat mit AutOP ').add_run(' Version ' + version)
font = run.font
font.name = 'Verdana'
font.size = Pt(8)
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('')

print('***   1 Abkürzungsverzeichnis   ***')
obf_doc.doc.add_heading('Abkürzungsverzeichnis', 1)

obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('Die folgenden Abkürzungen werden in den Tabellen verwendet um die Lesbarkeit und Übersicht der Tabellen zu gewähleisten')
obf_doc.doc.add_paragraph('')

obf_doc.doc.add_heading('Spaltenüberschriften', 2)

obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('Alle nachfolgenden Tabellen verwenden diese Abkürzungen in den Spaltenüberschriften')
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('Abt		...	Abteilung')
obf_doc.doc.add_paragraph('UAbt		...	Unterabteilung')
obf_doc.doc.add_paragraph('Tfl		...	Teilfläche')
obf_doc.doc.add_paragraph('WE Typ	...	Abteilung')
obf_doc.doc.add_paragraph('BKL		...	Betriebsklasse')
obf_doc.doc.add_paragraph('UZ		...	Umtriebszeit')
obf_doc.doc.add_paragraph('Etrs		...	Ertragssituation')
obf_doc.doc.add_paragraph('BW Typ	...	Bewirtschaftungsform')
obf_doc.doc.add_paragraph('SW Typ	...	Schutzwaldkategorie')
obf_doc.doc.add_paragraph('NG Typ	...	Nebengrund Art')
obf_doc.doc.add_paragraph('Fl WW		...	Wirtschaftswaldfläche')
obf_doc.doc.add_paragraph('Fl SW		...	Schutzwaldfläche')
obf_doc.doc.add_paragraph('Fl NHB		...	Nichtholzbodenfläche')
obf_doc.doc.add_paragraph('Fl pNG		...	produktiver Nebengrund')
obf_doc.doc.add_paragraph('Fl uNG		...	unproduktiver Nebengrund')
obf_doc.doc.add_paragraph('Fl Ges		...	Gesamtfläche')
obf_doc.doc.add_paragraph('')

obf_doc.doc.add_page_break()

obf_doc.doc.add_heading('Abkürzungen von Werten', 2)

obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('Alle nachfolgenden Tabellen verwenden diese Abkürzungen von Werten innerhalb der Tabellen')
obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('WE Typ')
p.font.bold = True
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('WO	...	Waldort')
obf_doc.doc.add_paragraph('NG	...	Nebengrund')
obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Ertragssituation')
p.font.bold = True
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('I	...	in Ertrag')
obf_doc.doc.add_paragraph('A	...	außer Ertrag')
obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Bewirtschaftungsform')
p.font.bold = True
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('W	...	Wirtschaftswald')
obf_doc.doc.add_paragraph('S	...	Schutzwald')
obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Schutzwaldkategorie')
p.font.bold = True
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('S	...	Standortsschutzwald')
obf_doc.doc.add_paragraph('O	...	Objektschutzwald')
obf_doc.doc.add_paragraph('B	...	Bannwald')
obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Nebengrund Art')
p.font.bold = True
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('1	...	Standortsschutzwald')
obf_doc.doc.add_paragraph('2	...	Bergkiefer (Latschen)')
obf_doc.doc.add_paragraph('3	...	Straße (Forststraßen, Schlepperwege')
obf_doc.doc.add_paragraph('4	...	')
obf_doc.doc.add_paragraph('5	...	Wiese')
obf_doc.doc.add_paragraph('6	...	Acker')
obf_doc.doc.add_paragraph('7	...	Gewässer (Bäche, Flüsse, Teiche, Seen)')
obf_doc.doc.add_paragraph('8	...	Felsen, Geröll')
obf_doc.doc.add_paragraph('9	...	')
obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Flächen')
p.font.bold = True
obf_doc.doc.add_paragraph('')
obf_doc.doc.add_paragraph('Wirtschaftswaldfläche	...	Wirtschaftswald')
obf_doc.doc.add_paragraph('Schutzwaldfläche		...	Schutzwald')
obf_doc.doc.add_paragraph('Nichtholzbodenfläche		...	Nebengrund Art 3 & 4')
obf_doc.doc.add_paragraph('produktiver Nebengrund	...	Nebengrund Art 5 & 6')
obf_doc.doc.add_paragraph('produktiver Nebengrund	...	Nebengrund Art 1 & 2 & 7 & 8 & 9')
obf_doc.doc.add_paragraph('Gesamtfläche			...	alle Flächen summiert')
obf_doc.doc.add_paragraph('')


obf_doc.doc.add_page_break()

#############################
###   2 Flächentabellen   ###
#############################

print('***   2 Flächentabellen   ***')
obf_doc.doc.add_heading('Flächentabellen', 1)
obf_doc.doc.add_paragraph('')

obf_doc.doc.add_heading('FR Kierling', 2)
obf_doc.doc.add_paragraph('')

fr = 1
for abt in flt.fr_abt[fr-1][0:5]:
    print(abt)
    table = flt.create_table(fr, abt)
    width = [2,2,2,2,2,3,2,2,2,2,2,2,2,2,2,2,2]
    obf_doc.docx_table_text(table, width, header_rep = True, header = 'Abteilung - '+ str(abt), font_size = 7, autofit = True)
    obf_doc.doc.add_paragraph('')
    obf_doc.doc.add_paragraph('')
    
# save the doc
path_save = os.path.join(temp_path, 'flaechentabelle.docx')
obf_doc.doc.save(path_save)

print('end')
print('successfully made')
# Out:
# ***   0 Deckblatt   ***
# ***   1 Abkürzungsverzeichnis   ***
# ***   2 Flächentabellen   ***
# 506
# 507
# 508
# 509
# 510
# end
# successfully made

# %%
x.shape
# Out:
# (19, 16)

# %%
x = x[['Forstrevier', 'Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse', 'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation', 'Bewirtschaftungsform', 'Schutzwaldkategorie', 'fl_ww', 'fl_sw', 'fl_nh', 'fl_rest']]
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 804             1        506            A        0     WO          9010.0
# 994             1        506            B        1     WO          9010.0
# 959             1        506            B        2     WO          9010.0
# 955             1        506            C        1     WO          9010.0
# 928             1        506            C        2     WO          9010.0
# 906             1        506            D        1     WO          9010.0
# 885             1        506            D        2     WO          9010.0
# 859             1        506            D        3     WO          9010.0
# 843             1        506            D        4     WO          9010.0
# 963             1        506            E        1     WO          9050.0
# 933             1        506            E        2     WO          9010.0
# 909             1        506            F        1     WO          9050.0
# 882             1        506            F        2     WO          9010.0
# 849             1        506            G        1     WO          9010.0
# 830             1        506            G        2     WO          9010.0
# 718             1        506            3        1     NG             NaN
# 714             1        506            5        1     NG             NaN
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 804            140             NaN                I                    W
# 994            140             NaN                I                    W
# 959            140             NaN                I                    W
# 955            140             NaN                I                    W
# 928            140             NaN                I                    W
# 906            140             NaN                I                    W
# 885            140             NaN                I                    W
# 859            140             NaN                I                    W
# 843            140             NaN                I                    W
# 963            160             NaN                I                    W
# 933            140             NaN                I                    W
# 909            160             NaN                I                    W
# 882            140             NaN                I                    W
# 849            140             NaN                I                    W
# 830            140             NaN                I                    W
# 718              0             3.0              NaN                  NaN
# 714              0             5.0              NaN                  NaN
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  fl_ww  fl_sw  fl_nh  fl_rest
# 804                   NaN   8.69    NaN    NaN      NaN
# 994                   NaN   0.81    NaN    NaN      NaN
# 959                   NaN   0.63    NaN    NaN      NaN
# 955                   NaN   3.24    NaN    NaN      NaN
# 928                   NaN   2.93    NaN    NaN      NaN
# 906                   NaN   1.96    NaN    NaN      NaN
# 885                   NaN   1.14    NaN    NaN      NaN
# 859                   NaN   1.42    NaN    NaN      NaN
# 843                   NaN   1.39    NaN    NaN      NaN
# 963                   NaN   2.88    NaN    NaN      NaN
# 933                   NaN   0.92    NaN    NaN      NaN
# 909                   NaN   3.45    NaN    NaN      NaN
# 882                   NaN   1.27    NaN    NaN      NaN
# 849                   NaN   1.98    NaN    NaN      NaN
# 830                   NaN   0.37    NaN    NaN      NaN
# 718                   NaN    NaN    NaN   2.03      NaN
# 714                   NaN    NaN    NaN    NaN      NaN
# 710                   NaN    NaN    NaN    NaN     0.24
# 4512                  NaN    NaN    NaN    NaN     0.38

# %%
def run():
    '''
        run program
    '''
    
    obf_doc = OBFDocX(Document(temp_path + '/templet_xx.docx'))

    version = '3.8'
    
    print('***   0 Deckblatt   ***')

    obf_doc.doc.add_picture(temp_path + '/oebf.png')

    for i in range(4):
        obf_doc.doc.add_paragraph('')

    p = obf_doc.doc.add_paragraph().add_run('OPERAT')
    p.bold = True
    p.font.name = 'Verdana'
    p.font.size = Pt(34)

    p = obf_doc.doc.add_paragraph().add_run('FB ') #+ str(obf_fuc.dic.fb) + ' ' + obf_fuc.dic.dic_num_fb[obf_fuc.dic.fb])
    p.bold = True
    p.font.name = 'Verdana'
    p.font.size = Pt(35)

    obf_doc.doc.add_paragraph('')

    p = obf_doc.doc.add_paragraph().add_run('Teiloperat ') #+ str(obf_fuc.dic.to))
    p.font.name = 'Verdana'
    p.font.size = Pt(25)

    for i in range(3):
        obf_doc.doc.add_paragraph('')

    for i in obf_fuc.loop_fr()[1:]:

        p = obf_doc.doc.add_paragraph().add_run(obf_fuc.name_code(i)[1])
        p.font.name = 'Verdana'
        p.font.size = Pt(20)

    for i in range(12-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
        p = obf_doc.doc.add_paragraph().add_run('')
        p.font.size = Pt(20)

    p = obf_doc.doc.add_paragraph().add_run('Organisationsstand 01.01.' + obf_fuc.dic.laufzeit_begin)
    p.font.name = 'Verdana'
    p.font.size = Pt(18)

    p = obf_doc.doc.add_paragraph().add_run('Laufzeit 01.01.' + obf_fuc.dic.laufzeit_begin + ' - 31.12.' + obf_fuc.dic.laufzeit_end)
    p.font.name = 'Verdana'
    p.font.size = Pt(18)

    for i in range(10-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
        obf_doc.doc.add_paragraph('')

    p = obf_doc.doc.add_paragraph().add_run('Für die Unternehmensleitung                       Für der Forstbetrieb')
    p.font.name = 'Verdana'
    p.font.size = Pt(12)

    obf_doc.doc.add_page_break()

    for i in range(3):
        obf_doc.doc.add_paragraph('')

    run = obf_doc.doc.add_paragraph('Erstellung vom Teiloperat mit AutOP ').add_run(' Version ' + version)
    font = run.font
    font.name = 'Verdana'
    font.size = Pt(8)
    
    # save the doc
    path_save = os.path.join(self.data_path, 'flaechentabelle_' + str(obf_fuc.dic.to) + '.docx')
    obf_doc.doc.save(path_save)

    print('end')
    return('successfully made')

# %%
data_path
# Out:
# '/Users/philipp/Data/obf_autop'

# %%
flur_path = data_path + '/flurnamen/Flurnamen_2018.xlsx'
flur = pd.read_excel(flur_path)

# %%
flur
# Out:
#        FB  FR  ABT                Flurname
# 0     171   1  506  Vorderer Sachsengraben
# 1     171   1  507  Hinterer Sachsengraben
# 2     171   1  508  Hinterer Sachsengraben
# 3     171   1  509           Meidlingsteig
# 4     171   1  510              Ziegelmais
# 5     171   1  511               Sauwinkel
# 6     171   1  512               Sauwinkel
# 7     171   1  513              Ziegelmais
# 8     171   1  514           Meidlingsteig
# 9     171   1  515    Hinterer Sachsgraben
# 10    171   1  516    Hinterer Sachsgraben
# 11    171   1  517    Vorderer Sachsgraben
# 12    171   1  518               Rotgraben
# 13    171   1  519               Rotgraben
# 14    171   1  520               Sauleiten
# 15    171   1  521            Gsaengerwald
# 16    171   1  522            Gsaengerwald
# 17    171   1  523                 Obereck
# 18    171   1  524                 Obereck
# 19    171   1  533                 Heuberg
# 20    171   1  534                 Heuberg
# 21    171   1  535                 Heuberg
# 22    171   1  536                 Heuberg
# 23    171   1  537     Goettweiher Heuberg
# 24    171   1  538     Goettweiher Heuberg
# 25    171   1  595             Reiter Mais
# 26    171   1  596         Zaunbogenhuette
# 27    171   1  597         Zaunbogenhuette
# 28    171   1  598               Rauchbach
# 29    171   1  599         Zaunbogenhuette
# ...   ...  ..  ...                     ...
# 2168  180  10  420          Kirchentalwald
# 2169  180  10  421          Dürrschuttwald
# 2170  180  10  422              Kleberwald
# 2171  180  10  423      Wildenbachhofsache
# 2172  180  10  424      Wildenbachhofsache
# 2173  180  10  425              Struppberg
# 2174  180  10  426               Hundsfuss
# 2175  180  10  427      Wildenbachhofsache
# 2176  180  10  428          Kleberhofsache
# 2177  180  10  429        Dürnberghofsache
# 2178  180  10  430        Dürnberghofsache
# 2179  180  10  431        Dürnberghofsache
# 2180  180  10  432           Römerbannwald
# 2181  180  10  433           Römerbannwald
# 2182  180  10  434        Schiederhofsache
# 2183  180  10  435        Schiederhofsache
# 2184  180  10  436        Schiederhofsache
# 2185  180  10  437        Schiederhofsache
# 2186  180  10  438        Schiederhofsache
# 2187  180  10  439        Schiederhofsache
# 2188  180  10  440      Heitzmannshofsache
# 2189  180  10  441              Mühlleiten
# 2190  180  10  442              Schornwald
# 2191  180  10  443                Diesbach
# 2192  180  10  444            Brentnerwald
# 2193  180  10  445              Fockenwald
# 2194  180  10  446            Sellauerwald
# 2195  180  10  447           Gasteigerwald
# 2196  180  10  448       Hallensteinerwald
# 2197  180  10  449            Brentnermahd
#
# [2198 rows x 4 columns]
