# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import docx

from docx import Document
from docx.oxml import OxmlElement
from docx.oxml.ns import qn
from docx.shared import Cm
from docx.shared import Pt

from docx.enum.section import WD_ORIENT
from docx.enum.section import WD_SECTION

# %%
# set home directory
home_path = os.getcwd()[:os.getcwd().find('Code/obf_autop')-1]
# set data_path
data_path = os.path.join(home_path, 'Data', 'obf_autop', 'TO1356', 'to_1356_sap.XLS')

# %%
data_path
# Out:
# '/Users/philipp/Data/obf_autop/TO1356/to_1356_sap.XLS'

# %%
data_raw = pd.read_csv(data_path, sep='\t', encoding = "ISO-8859-1", decimal=',', error_bad_lines=False)
# Out:
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (147,148,149) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Flaeche der WO (2.1)
data_wo_fl = data_raw[data_raw['Schichtalter'] == 0]

# %%
data_wo_fl
# Out:
#        Merkmalausprägung  AuswKatTyp  Teiloperats-ID  Forstbetrieb  Debitor  \
# 0                      0         NaN            1356           171   220442
# 1                      0         NaN            1356           171   220442
# 2                      0         NaN            1356           171   220442
# 3                      0         NaN            1356           171   220442
# 4                      0         NaN            1356           171   220442
# 5                      0         NaN            1356           171   220442
# 6                      0         NaN            1356           171   220442
# 7                      0         NaN            1356           171   220442
# 8                      0         NaN            1356           171   220442
# 9                      0         NaN            1356           171   220442
# 10                     0         NaN            1356           171   220442
# 11                     0         NaN            1356           171   220442
# 12                     0         NaN            1356           171   220442
# 13                     0         NaN            1356           171   220442
# 14                     0         NaN            1356           171   220442
# 15                     0         NaN            1356           171   220442
# 16                     0         NaN            1356           171   220442
# 17                     0         NaN            1356           171   220442
# 18                     0         NaN            1356           171   220442
# 19                     0         NaN            1356           171   220442
# 20                     0         NaN            1356           171   220442
# 21                     0         NaN            1356           171   220442
# 22                     0         NaN            1356           171   220442
# 23                     0         NaN            1356           171   220442
# 24                     0         NaN            1356           171   220442
# 25                     0         NaN            1356           171   220442
# 26                     0         NaN            1356           171   220442
# 27                     0         NaN            1356           171   220442
# 28                     0         NaN            1356           171   220442
# 29                     0         NaN            1356           171   220442
# ...                  ...         ...             ...           ...      ...
# 34051                  0         NaN            1356           171   220442
# 34060                  0         NaN            1356           171   220442
# 34073                  0         NaN            1356           171   220442
# 34083                  0         NaN            1356           171   220442
# 34087                  0         NaN            1356           171   220442
# 34101                  0         NaN            1356           171   220442
# 34113                  0         NaN            1356           171   220442
# 34127                  0         NaN            1356           171   220442
# 34133                  0         NaN            1356           171   220442
# 34146                  0         NaN            1356           171   220442
# 34151                  0         NaN            1356           171   220442
# 34157                  0         NaN            1356           171   220442
# 34166                  0         NaN            1356           171   220442
# 34179                  0         NaN            1356           171   220442
# 34188                  0         NaN            1356           171   220442
# 34195                  0         NaN            1356           171   220442
# 34210                  0         NaN            1356           171   220442
# 34219                  0         NaN            1356           171   220442
# 34227                  0         NaN            1356           171   220442
# 34232                  0         NaN            1356           171   220442
# 34247                  0         NaN            1356           171   220442
# 34253                  0         NaN            1356           171   220442
# 34259                  0         NaN            1356           171   220442
# 34271                  0         NaN            1356           171   220442
# 34286                  0         NaN            1356           171   220442
# 34293                  0         NaN            1356           171   220442
# 34301                  0         NaN            1356           171   220442
# 34312                  0         NaN            1356           171   220442
# 34323                  0         NaN            1356           171   220442
# 34331                  0         NaN            1356           171   220442
#
#       TO-Bezeichnung  Status Beg. Laufzeit Ende Laufzeit  Operat-ID  \
# 0            FE 2019       2    01.01.2020    31.12.2029        291
# 1            FE 2019       2    01.01.2020    31.12.2029        291
# 2            FE 2019       2    01.01.2020    31.12.2029        291
# 3            FE 2019       2    01.01.2020    31.12.2029        291
# 4            FE 2019       2    01.01.2020    31.12.2029        291
# 5            FE 2019       2    01.01.2020    31.12.2029        291
# 6            FE 2019       2    01.01.2020    31.12.2029        291
# 7            FE 2019       2    01.01.2020    31.12.2029        291
# 8            FE 2019       2    01.01.2020    31.12.2029        291
# 9            FE 2019       2    01.01.2020    31.12.2029        291
# 10           FE 2019       2    01.01.2020    31.12.2029        291
# 11           FE 2019       2    01.01.2020    31.12.2029        291
# 12           FE 2019       2    01.01.2020    31.12.2029        291
# 13           FE 2019       2    01.01.2020    31.12.2029        291
# 14           FE 2019       2    01.01.2020    31.12.2029        291
# 15           FE 2019       2    01.01.2020    31.12.2029        291
# 16           FE 2019       2    01.01.2020    31.12.2029        291
# 17           FE 2019       2    01.01.2020    31.12.2029        291
# 18           FE 2019       2    01.01.2020    31.12.2029        291
# 19           FE 2019       2    01.01.2020    31.12.2029        291
# 20           FE 2019       2    01.01.2020    31.12.2029        291
# 21           FE 2019       2    01.01.2020    31.12.2029        291
# 22           FE 2019       2    01.01.2020    31.12.2029        291
# 23           FE 2019       2    01.01.2020    31.12.2029        291
# 24           FE 2019       2    01.01.2020    31.12.2029        291
# 25           FE 2019       2    01.01.2020    31.12.2029        291
# 26           FE 2019       2    01.01.2020    31.12.2029        291
# 27           FE 2019       2    01.01.2020    31.12.2029        291
# 28           FE 2019       2    01.01.2020    31.12.2029        291
# 29           FE 2019       2    01.01.2020    31.12.2029        291
# ...              ...     ...           ...           ...        ...
# 34051        FE 2019       2    01.01.2020    31.12.2029        291
# 34060        FE 2019       2    01.01.2020    31.12.2029        291
# 34073        FE 2019       2    01.01.2020    31.12.2029        291
# 34083        FE 2019       2    01.01.2020    31.12.2029        291
# 34087        FE 2019       2    01.01.2020    31.12.2029        291
# 34101        FE 2019       2    01.01.2020    31.12.2029        291
# 34113        FE 2019       2    01.01.2020    31.12.2029        291
# 34127        FE 2019       2    01.01.2020    31.12.2029        291
# 34133        FE 2019       2    01.01.2020    31.12.2029        291
# 34146        FE 2019       2    01.01.2020    31.12.2029        291
# 34151        FE 2019       2    01.01.2020    31.12.2029        291
# 34157        FE 2019       2    01.01.2020    31.12.2029        291
# 34166        FE 2019       2    01.01.2020    31.12.2029        291
# 34179        FE 2019       2    01.01.2020    31.12.2029        291
# 34188        FE 2019       2    01.01.2020    31.12.2029        291
# 34195        FE 2019       2    01.01.2020    31.12.2029        291
# 34210        FE 2019       2    01.01.2020    31.12.2029        291
# 34219        FE 2019       2    01.01.2020    31.12.2029        291
# 34227        FE 2019       2    01.01.2020    31.12.2029        291
# 34232        FE 2019       2    01.01.2020    31.12.2029        291
# 34247        FE 2019       2    01.01.2020    31.12.2029        291
# 34253        FE 2019       2    01.01.2020    31.12.2029        291
# 34259        FE 2019       2    01.01.2020    31.12.2029        291
# 34271        FE 2019       2    01.01.2020    31.12.2029        291
# 34286        FE 2019       2    01.01.2020    31.12.2029        291
# 34293        FE 2019       2    01.01.2020    31.12.2029        291
# 34301        FE 2019       2    01.01.2020    31.12.2029        291
# 34312        FE 2019       2    01.01.2020    31.12.2029        291
# 34323        FE 2019       2    01.01.2020    31.12.2029        291
# 34331        FE 2019       2    01.01.2020    31.12.2029        291
#
#            ...                                                  Zeile1  \
# 0          ...                                                     NaN
# 1          ...                                                     NaN
# 2          ...                                                     NaN
# 3          ...                                                     NaN
# 4          ...                                                     NaN
# 5          ...                                                     NaN
# 6          ...                                                     NaN
# 7          ...                                                     NaN
# 8          ...                                                     NaN
# 9          ...                                                     NaN
# 10         ...                                                     NaN
# 11         ...                                                     NaN
# 12         ...                                                     NaN
# 13         ...                                                     NaN
# 14         ...                                                     NaN
# 15         ...                                                     NaN
# 16         ...                                                     NaN
# 17         ...                                                     NaN
# 18         ...                                                     NaN
# 19         ...                                                     NaN
# 20         ...                                                     NaN
# 21         ...                                                     NaN
# 22         ...                                                     NaN
# 23         ...                                                     NaN
# 24         ...                                                     NaN
# 25         ...                                                     NaN
# 26         ...                                                     NaN
# 27         ...                                                     NaN
# 28         ...                                                     NaN
# 29         ...                                                     NaN
# ...        ...                                                     ...
# 34051      ...                        BE   ungleichaltrig -5/+10 Jahre
# 34060      ...        BE   ungleichaltrig +/- 5 Jahre, zahlreich KI ER
# 34073      ...                                         ST   STOE 88-96
# 34083      ...               MA   als Windmantel für "296 B1" belassen
# 34087      ...       BE   ungleichaltrig jüngerer Teil im Osten, me...
# 34101      ...               BE   stark verkrautet, Straßenbeleuchtung
# 34113      ...                                      ST   STOE 88-89-96
# 34127      ...                BE   zahlreich Nussbäume aus Kultur 1993
# 34133      ...                                         ST   STOE 88-96
# 34146      ...                                            ST   2 Teile
# 34151      ...        BE   ehemaliger Zaunfläche, einige EI-Überhälter
# 34157      ...       BE   ungleichaltrig+/- 5 Jahre, einzelne WB SP...
# 34166      ...       BE   schlechte Qualität der BU, BU-TA-FI-Natur...
# 34179      ...                                      ST   Grabeneinhang
# 34188      ...       BE   im SüdWesten licht mit BU-BI-KI-Naturverj...
# 34195      ...                                         ST   STOE 76-86
# 34210      ...                                            ST   3 Teile
# 34219      ...                                            ST   2 Teile
# 34227      ...           BE   WindWurf-Fläche nach RM im NordNordOsten
# 34232      ...                                         ST   STOE 86-88
# 34247      ...                  BE   ehemalige WindWurf-Fläche, Hopfen
# 34253      ...                                                     NaN
# 34259      ...       BE   ungleichaltrig - in der Mitte jünger, Süd...
# 34271      ...                                         ST   STOE 76-86
# 34286      ...       BE   1988 genutzte Fläche mit Naturverjüngung ...
# 34293      ...                BE   Überhälter im SüdOsten, einzelne BI
# 34301      ...                                         ST   STOE 76-86
# 34312      ...                                  BE   NH stark bedrängt
# 34323      ...                              ST   ehemaliger Steinbruch
# 34331      ...                   ST   ehemaliger Steinbruch, Sendemast
#
#                                                   Zeile2  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 34051                                                NaN
# 34060                    MA   Monosäulenreste einsammeln
# 34073  BE   ungleichaltrig +/- 5 Jahre, einzelne Elsb...
# 34083                                                NaN
# 34087         teils unterdrückt, geringe Qualität der BU
# 34101                                                NaN
# 34113  BE   einzelne KB ER Pappeln, 2003-2004 durchfo...
# 34127                                                NaN
# 34133  BE   einzelne ES UL KB ER, Linden geringe Qual...
# 34146                          BE   einzelne KB, rotfaul
# 34151                                                NaN
# 34157     derLA, gesetzte Bäume teils umgeknickt, Hopfen
# 34166                                                NaN
# 34179  BE   FI rotfaul im NordOsten, in der Mitte feu...
# 34188                                                NaN
# 34195  BE   ungleichaltrig, einzelne EI, im NordWeste...
# 34210                                     BE   starke TA
# 34219           BE   ungleichaltrig teils 5 Jahre jünger
# 34227                                                NaN
# 34232  BE   zahlreich ER, im SüdWesten Nassgalle mit ...
# 34247                                                NaN
# 34253                                                NaN
# 34259                                  Westen sehr dicht
# 34271  BE   einzelne BI TA, EI oft mikrig und eingewa...
# 34286      FI-Kultur im NordWesten, BI zurückgeschnitten
# 34293                                                NaN
# 34301                                BE   NH eingezwickt
# 34312                                                NaN
# 34323  BE   verwildert mit Waldrebe, Lücken, Tot- und...
# 34331  BE   Totholz, KI im Süden an der Grenze sehr d...
#
#                                                   Zeile3  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 34051                                                NaN
# 34060                                                NaN
# 34073                                                NaN
# 34083                                                NaN
# 34087                           MA   aufwendige Bringung
# 34101                                                NaN
# 34113   100Efm, tolle TA-Naturverjüngung, plenterarti...
# 34127                                                NaN
# 34133                                                NaN
# 34146                                                NaN
# 34151                                                NaN
# 34157                                                NaN
# 34166                                                NaN
# 34179      einzelne EI, im Süden Wiesenrandbäume - älter
# 34188                                                NaN
# 34195   ältere KI, 2000 außerplanmäßige Räumung im No...
# 34210                                                NaN
# 34219                                                NaN
# 34227                                                NaN
# 34232                                                NaN
# 34247                                                NaN
# 34253                                                NaN
# 34259                            MA   FI teils erntereif
# 34271                                                NaN
# 34286                                                NaN
# 34293                                                NaN
# 34301                                                NaN
# 34312                                                NaN
# 34323                                            Schicht
# 34331                                MA   Naturwaldzelle
#
#                                      Zeile4 Zeile5  Zeile6  Zeile7  Zeile8  \
# 0                                       NaN    NaN     NaN     NaN     NaN
# 1                                       NaN    NaN     NaN     NaN     NaN
# 2                                       NaN    NaN     NaN     NaN     NaN
# 3                                       NaN    NaN     NaN     NaN     NaN
# 4                                       NaN    NaN     NaN     NaN     NaN
# 5                                       NaN    NaN     NaN     NaN     NaN
# 6                                       NaN    NaN     NaN     NaN     NaN
# 7                                       NaN    NaN     NaN     NaN     NaN
# 8                                       NaN    NaN     NaN     NaN     NaN
# 9                                       NaN    NaN     NaN     NaN     NaN
# 10                                      NaN    NaN     NaN     NaN     NaN
# 11                                      NaN    NaN     NaN     NaN     NaN
# 12                                      NaN    NaN     NaN     NaN     NaN
# 13                                      NaN    NaN     NaN     NaN     NaN
# 14                                      NaN    NaN     NaN     NaN     NaN
# 15                                      NaN    NaN     NaN     NaN     NaN
# 16                                      NaN    NaN     NaN     NaN     NaN
# 17                                      NaN    NaN     NaN     NaN     NaN
# 18                                      NaN    NaN     NaN     NaN     NaN
# 19                                      NaN    NaN     NaN     NaN     NaN
# 20                                      NaN    NaN     NaN     NaN     NaN
# 21                                      NaN    NaN     NaN     NaN     NaN
# 22                                      NaN    NaN     NaN     NaN     NaN
# 23                                      NaN    NaN     NaN     NaN     NaN
# 24                                      NaN    NaN     NaN     NaN     NaN
# 25                                      NaN    NaN     NaN     NaN     NaN
# 26                                      NaN    NaN     NaN     NaN     NaN
# 27                                      NaN    NaN     NaN     NaN     NaN
# 28                                      NaN    NaN     NaN     NaN     NaN
# 29                                      NaN    NaN     NaN     NaN     NaN
# ...                                     ...    ...     ...     ...     ...
# 34051                                   NaN    NaN     NaN     NaN     NaN
# 34060                                   NaN    NaN     NaN     NaN     NaN
# 34073                                   NaN    NaN     NaN     NaN     NaN
# 34083                                   NaN    NaN     NaN     NaN     NaN
# 34087                                   NaN    NaN     NaN     NaN     NaN
# 34101                                   NaN    NaN     NaN     NaN     NaN
# 34113  MA   Siedlungsgebiet - Wegesicherung    NaN     NaN     NaN     NaN
# 34127                                   NaN    NaN     NaN     NaN     NaN
# 34133                                   NaN    NaN     NaN     NaN     NaN
# 34146                                   NaN    NaN     NaN     NaN     NaN
# 34151                                   NaN    NaN     NaN     NaN     NaN
# 34157                                   NaN    NaN     NaN     NaN     NaN
# 34166                                   NaN    NaN     NaN     NaN     NaN
# 34179                                   NaN    NaN     NaN     NaN     NaN
# 34188                                   NaN    NaN     NaN     NaN     NaN
# 34195         indeinrisse, tolle 2. Schicht    NaN     NaN     NaN     NaN
# 34210                                   NaN    NaN     NaN     NaN     NaN
# 34219                                   NaN    NaN     NaN     NaN     NaN
# 34227                                   NaN    NaN     NaN     NaN     NaN
# 34232                                   NaN    NaN     NaN     NaN     NaN
# 34247                                   NaN    NaN     NaN     NaN     NaN
# 34253                                   NaN    NaN     NaN     NaN     NaN
# 34259                                   NaN    NaN     NaN     NaN     NaN
# 34271                                   NaN    NaN     NaN     NaN     NaN
# 34286                                   NaN    NaN     NaN     NaN     NaN
# 34293                                   NaN    NaN     NaN     NaN     NaN
# 34301                                   NaN    NaN     NaN     NaN     NaN
# 34312                                   NaN    NaN     NaN     NaN     NaN
# 34323                                   NaN    NaN     NaN     NaN     NaN
# 34331                                   NaN    NaN     NaN     NaN     NaN
#
#        Bestockungsziel Flächenanteil
# 0                  NaN           0.0
# 1                  NaN           0.0
# 2                  NaN           0.0
# 3                  NaN           0.0
# 4                  NaN           0.0
# 5                  NaN           0.0
# 6                  NaN           0.0
# 7                  NaN           0.0
# 8                  NaN           0.0
# 9                  NaN           0.0
# 10                 NaN           0.0
# 11                 NaN           0.0
# 12                 NaN           0.0
# 13                 NaN           0.0
# 14                 NaN           0.0
# 15                 NaN           0.0
# 16                 NaN           0.0
# 17                 NaN           0.0
# 18                 NaN           0.0
# 19                 NaN           0.0
# 20                 NaN           0.0
# 21                 NaN           0.0
# 22                 NaN           0.0
# 23                 NaN           0.0
# 24                 NaN           0.0
# 25                 NaN           0.0
# 26                 NaN           0.0
# 27                 NaN           0.0
# 28                 NaN           0.0
# 29                 NaN           0.0
# ...                ...           ...
# 34051      2SL 2TA 6BU           0.0
# 34060          2SL 8BU           0.0
# 34073          5BU 5LA           0.0
# 34083          1SL 9BU           0.0
# 34087          2SL 8BU           0.0
# 34101      4SL 5BU 1TA           0.0
# 34113      2SL 7BU 1TA           0.0
# 34127          5SL 5BU           0.0
# 34133          3SL 7BU           0.0
# 34146          5LA 5BU           0.0
# 34151          3HB 7EI           0.0
# 34157      1BU 6LA 3TA           0.0
# 34166          5BU 5LA           0.0
# 34179          5BU 5LA           0.0
# 34188      1TA 5BU 4LA           0.0
# 34195      3LA 2TA 5BU           0.0
# 34210      3LA 2TA 5BU           0.0
# 34219      3LA 2TA 5BU           0.0
# 34227          7LA 3BU           0.0
# 34232      4LA 5BU 1TA           0.0
# 34247          5BU 5LA           0.0
# 34253          5BU 5LA           0.0
# 34259      1TA 5BU 4LA           0.0
# 34271          5BU 5LA           0.0
# 34286      3LA 2BU 5FI           0.0
# 34293      1TA 5BU 4LA           0.0
# 34301      5FI 2BU 3LA           0.0
# 34312          2SL 8BU           0.0
# 34323          5LA 5BU           0.0
# 34331      4BU 4EI 2SL           0.0
#
# [6071 rows x 152 columns]

# %%
data_wo_fl.columns[:100]
# Out:
# Index(['Merkmalausprägung', 'AuswKatTyp', 'Teiloperats-ID', 'Forstbetrieb',
#        'Debitor', 'TO-Bezeichnung', 'Status', 'Beg. Laufzeit', 'Ende Laufzeit',
#        'Operat-ID', 'vorgeschl. Hiebssatz', 'Verantwortlicher',
#        'Erfassungsstatus', 'Migriert?', 'GUID', 'Forstbetrieb.1',
#        'Teiloperats-ID.1', 'Forstrevier', 'Abteilung', 'Unterabteil.',
#        'Teilfl.', 'Debitor.1', 'Bearbeitungsblock', 'WE-Typ', 'Betriebsklasse',
#        'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation',
#        'Bewirtschaftungsform', 'Schutzwaldkategorie', 'Fläche in HA',
#        'Seehöhe', 'Exposition', 'Neigung', 'Standorteinheit', 'Vegetationstyp',
#        'Waldtyp', 'Wuchsgebiet', 'Überh. Laubholz', 'Überh. Nadelhz.',
#        'fr. Schälschade', 'Verbissgrad', 'SchutzwaldProjNr', 'Schlussgrad',
#        'Stabilität', 'VJ Bedingung', 'VJ Situation', 'Erreichbark. des BZ',
#        'Selektiver Verbiss', 'Erfassungsstatus.1', 'Storno', 'Angelegt von',
#        'Angelegt am', 'Uhrzeit', 'Geändert von', 'Geändert am', 'Uhrzeit.1',
#        'Waldort', 'GUID.1', 'GUID.2', 'Forstbetrieb.2', 'Teiloperats-ID.2',
#        'Forstrevier.1', 'Abteilung.1', 'Unterabteil..1', 'Teilfl..1',
#        'Best.-Schicht', 'Debitor.2', 'Schichtanteil', 'Schichtalter',
#        'S-Best.grad', 'Erfassungsstatus.2', 'Storno.1', 'GUID.3', 'GUID.4',
#        'Forstbetrieb.3', 'Teiloperats-ID.3', 'Forstrevier.2', 'Abteilung.2',
#        'Unterabteil..2', 'Teilfl..2', 'Best.-Schicht.1', 'Baumart',
#        'Debitor.3', 'Baumartenanteil', 'BaumartenBestockgrad', 'Schälgrad',
#        'Ertragsklasse', 'Vorrat / ha', 'Laubholzvorrat / ha',
#        'Nadelholzvorrat / ha', 'Vorrat am Ort', 'Laubholzvorrat Ort',
#        'Nadelholzvorrat Ort', 'GSOLL / HA', 'GIST / HA', 'lauf. Zuwachs / HA',
#        'DGZU / HA', 'HDZ', 'LGZ'],
#       dtype='object')

# %%
data_wo_fl = data_wo_fl[['Forstrevier','Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse',
       'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation',
       'Bewirtschaftungsform', 'Schutzwaldkategorie', 'Fläche in HA']]

# %%
fr = np.sort(data_wo_fl['Forstrevier'].unique())

# %%
data_wo_fl.loc[data_wo_fl['Forstrevier']==1,'Abteilung']
# Out:
# 702      599
# 703      659
# 704      719
# 705      519
# 706      599
# 707      659
# 708      519
# 709      719
# 710      506
# 711      598
# 712      519
# 713      659
# 714      506
# 715      719
# 716      597
# 717      519
# 718      506
# 719      658
# 720      718
# 721      596
# 722      518
# 723      657
# 724      518
# 725      595
# 726      717
# 727      657
# 728      518
# 729      538
# 730      717
# 731      518
#         ...
# 17774    515
# 17793    658
# 17809    597
# 17828    515
# 17848    523
# 17854    653
# 17857    515
# 17863    523
# 17869    597
# 17874    515
# 17882    653
# 17889    523
# 17895    658
# 17977    515
# 17981    704
# 17989    597
# 17996    715
# 18027    523
# 18034    515
# 18102    726
# 18203    515
# 18212    597
# 18217    653
# 18230    523
# 18236    515
# 18237    515
# 18238    515
# 18239    515
# 18240    657
# 18251    740
# Name: Abteilung, Length: 1156, dtype: int64

# %%
fr_abt = []
for f in fr:
    fr_abt.append(np.sort(data_wo_fl.loc[data_wo_fl['Forstrevier']==f,'Abteilung'].unique()))

# %%
fr_abt[0]
# Out:
# array([506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518,
#        519, 520, 521, 522, 523, 524, 533, 534, 535, 536, 537, 538, 595,
#        596, 597, 598, 599, 648, 649, 650, 651, 652, 653, 654, 655, 656,
#        657, 658, 659, 664, 700, 701, 702, 703, 704, 705, 706, 707, 708,
#        709, 710, 711, 712, 713, 714, 715, 716, 717, 718, 719, 720, 721,
#        722, 723, 724, 725, 726, 727, 728, 729, 730, 731, 732, 733, 734,
#        735, 736, 737, 738, 739, 740])

# %%
x = data_wo_fl.loc[(data_wo_fl['Forstrevier']==1) & (data_wo_fl['Abteilung']==506)]

# %%
x
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 710             1        506            9        1     NG             NaN
# 714             1        506            5        1     NG             NaN
# 718             1        506            3        1     NG             NaN
# 804             1        506            A        0     WO          9010.0
# 830             1        506            G        2     WO          9010.0
# 843             1        506            D        4     WO          9010.0
# 849             1        506            G        1     WO          9010.0
# 859             1        506            D        3     WO          9010.0
# 882             1        506            F        2     WO          9010.0
# 885             1        506            D        2     WO          9010.0
# 906             1        506            D        1     WO          9010.0
# 909             1        506            F        1     WO          9050.0
# 928             1        506            C        2     WO          9010.0
# 933             1        506            E        2     WO          9010.0
# 955             1        506            C        1     WO          9010.0
# 959             1        506            B        2     WO          9010.0
# 963             1        506            E        1     WO          9050.0
# 994             1        506            B        1     WO          9010.0
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 710              0             9.0              NaN                  NaN
# 714              0             5.0              NaN                  NaN
# 718              0             3.0              NaN                  NaN
# 804            140             NaN                I                    W
# 830            140             NaN                I                    W
# 843            140             NaN                I                    W
# 849            140             NaN                I                    W
# 859            140             NaN                I                    W
# 882            140             NaN                I                    W
# 885            140             NaN                I                    W
# 906            140             NaN                I                    W
# 909            160             NaN                I                    W
# 928            140             NaN                I                    W
# 933            140             NaN                I                    W
# 955            140             NaN                I                    W
# 959            140             NaN                I                    W
# 963            160             NaN                I                    W
# 994            140             NaN                I                    W
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  Fläche in HA
# 710                   NaN          0.24
# 714                   NaN          0.09
# 718                   NaN          2.03
# 804                   NaN          8.69
# 830                   NaN          0.37
# 843                   NaN          1.39
# 849                   NaN          1.98
# 859                   NaN          1.42
# 882                   NaN          1.27
# 885                   NaN          1.14
# 906                   NaN          1.96
# 909                   NaN          3.45
# 928                   NaN          2.93
# 933                   NaN          0.92
# 955                   NaN          3.24
# 959                   NaN          0.63
# 963                   NaN          2.88
# 994                   NaN          0.81
# 4512                  NaN          0.38

# %%
# sort WE-Typ , unterabteil. , Teilfl.

# %%
x.sort_values(['Abteilung', 'WE-Typ', 'Unterabteil.', 'Teilfl.'], ascending=[True, False, True, True])
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 804             1        506            A        0     WO          9010.0
# 994             1        506            B        1     WO          9010.0
# 959             1        506            B        2     WO          9010.0
# 955             1        506            C        1     WO          9010.0
# 928             1        506            C        2     WO          9010.0
# 906             1        506            D        1     WO          9010.0
# 885             1        506            D        2     WO          9010.0
# 859             1        506            D        3     WO          9010.0
# 843             1        506            D        4     WO          9010.0
# 963             1        506            E        1     WO          9050.0
# 933             1        506            E        2     WO          9010.0
# 909             1        506            F        1     WO          9050.0
# 882             1        506            F        2     WO          9010.0
# 849             1        506            G        1     WO          9010.0
# 830             1        506            G        2     WO          9010.0
# 718             1        506            3        1     NG             NaN
# 714             1        506            5        1     NG             NaN
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 804            140             NaN                I                    W
# 994            140             NaN                I                    W
# 959            140             NaN                I                    W
# 955            140             NaN                I                    W
# 928            140             NaN                I                    W
# 906            140             NaN                I                    W
# 885            140             NaN                I                    W
# 859            140             NaN                I                    W
# 843            140             NaN                I                    W
# 963            160             NaN                I                    W
# 933            140             NaN                I                    W
# 909            160             NaN                I                    W
# 882            140             NaN                I                    W
# 849            140             NaN                I                    W
# 830            140             NaN                I                    W
# 718              0             3.0              NaN                  NaN
# 714              0             5.0              NaN                  NaN
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  Fläche in HA
# 804                   NaN          8.69
# 994                   NaN          0.81
# 959                   NaN          0.63
# 955                   NaN          3.24
# 928                   NaN          2.93
# 906                   NaN          1.96
# 885                   NaN          1.14
# 859                   NaN          1.42
# 843                   NaN          1.39
# 963                   NaN          2.88
# 933                   NaN          0.92
# 909                   NaN          3.45
# 882                   NaN          1.27
# 849                   NaN          1.98
# 830                   NaN          0.37
# 718                   NaN          2.03
# 714                   NaN          0.09
# 710                   NaN          0.24
# 4512                  NaN          0.38

# %%
x[x['Nebengrund Art']==3.0]
# Out:
#      Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 718            1        506            3        1     NG             NaN
#
#      Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 718             0             3.0              NaN                  NaN
#
#      Schutzwaldkategorie  Fläche in HA
# 718                  NaN          2.03

# %%
x[x['Nebengrund Art']==9.0]
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  Fläche in HA
# 710                   NaN          0.24
# 4512                  NaN          0.38

# %%
x.loc[(x['Nebengrund Art']==3.0),'Fläche in HA']
# Out:
# 718    2.03
# Name: Fläche in HA, dtype: float64

# %%
x['fl_ww'] = x.loc[(x['Bewirtschaftungsform']=='W'),'Fläche in HA']
x['fl_sw'] = x.loc[(x['Bewirtschaftungsform']=='S'),'Fläche in HA']
x['fl_nh'] = x.loc[(x['Nebengrund Art']==3.0),'Fläche in HA']
x['fl_rest'] = x.loc[(x['Nebengrund Art']==9.0),'Fläche in HA']
# Out:
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/philipp/Python/anaconda3/envs/docx/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
x['fl_ww'].sum()
# Out:
# 33.080000000000005

# %%
xx = x.copy()

# %%
xx.loc['Total'] = pd.Series(xx['fl_ww'].sum(), index = ['fl_ww'])
xx.loc['Total'] = pd.Series(xx['fl_sw'].sum(), index = ['fl_sw'])
xx.loc['Total'] = pd.Series(xx['fl_nh'].sum(), index = ['fl_nh'])
xx.loc['Total'] = pd.Series(xx['fl_rest'].sum(), index = ['fl_rest'])

# %%
sum_df = {'fl_ww': xx['fl_ww'].sum(), 'fl_sw': xx['fl_sw'].sum(), 'fl_nh': xx['fl_nh'].sum(), 'fl_rest': xx['fl_rest'].sum()}

# %%
sum_df
# Out:
# {'fl_ww': 33.080000000000005, 'fl_sw': 0.0, 'fl_nh': 2.03, 'fl_rest': 0.62}

# %%
df = pd.DataFrame(data=sum_df, index = ["Total"])
df
# Out:
#        fl_ww  fl_sw  fl_nh  fl_rest
# Total  33.08    0.0   2.03     0.62

# %%
xx = xx.append(df)

# %%
xx
# Out:
#        Abteilung  Betriebsklasse Bewirtschaftungsform Ertragssituation  \
# 710        506.0             NaN                  NaN              NaN
# 714        506.0             NaN                  NaN              NaN
# 718        506.0             NaN                  NaN              NaN
# 804        506.0          9010.0                    W                I
# 830        506.0          9010.0                    W                I
# 843        506.0          9010.0                    W                I
# 849        506.0          9010.0                    W                I
# 859        506.0          9010.0                    W                I
# 882        506.0          9010.0                    W                I
# 885        506.0          9010.0                    W                I
# 906        506.0          9010.0                    W                I
# 909        506.0          9050.0                    W                I
# 928        506.0          9010.0                    W                I
# 933        506.0          9010.0                    W                I
# 955        506.0          9010.0                    W                I
# 959        506.0          9010.0                    W                I
# 963        506.0          9050.0                    W                I
# 994        506.0          9010.0                    W                I
# 4512       506.0             NaN                  NaN              NaN
# Total        NaN             NaN                  NaN              NaN
#
#        Fläche in HA  Forstrevier  Nebengrund Art  Schutzwaldkategorie  \
# 710            0.24          1.0             9.0                  NaN
# 714            0.09          1.0             5.0                  NaN
# 718            2.03          1.0             3.0                  NaN
# 804            8.69          1.0             NaN                  NaN
# 830            0.37          1.0             NaN                  NaN
# 843            1.39          1.0             NaN                  NaN
# 849            1.98          1.0             NaN                  NaN
# 859            1.42          1.0             NaN                  NaN
# 882            1.27          1.0             NaN                  NaN
# 885            1.14          1.0             NaN                  NaN
# 906            1.96          1.0             NaN                  NaN
# 909            3.45          1.0             NaN                  NaN
# 928            2.93          1.0             NaN                  NaN
# 933            0.92          1.0             NaN                  NaN
# 955            3.24          1.0             NaN                  NaN
# 959            0.63          1.0             NaN                  NaN
# 963            2.88          1.0             NaN                  NaN
# 994            0.81          1.0             NaN                  NaN
# 4512           0.38          1.0             9.0                  NaN
# Total           NaN          NaN             NaN                  NaN
#
#        Teilfl.  Umtriebszeit Unterabteil. WE-Typ  fl_nh  fl_rest  fl_sw  fl_ww
# 710        1.0           0.0            9     NG    NaN     0.24    NaN    NaN
# 714        1.0           0.0            5     NG    NaN      NaN    NaN    NaN
# 718        1.0           0.0            3     NG   2.03      NaN    NaN    NaN
# 804        0.0         140.0            A     WO    NaN      NaN    NaN   8.69
# 830        2.0         140.0            G     WO    NaN      NaN    NaN   0.37
# 843        4.0         140.0            D     WO    NaN      NaN    NaN   1.39
# 849        1.0         140.0            G     WO    NaN      NaN    NaN   1.98
# 859        3.0         140.0            D     WO    NaN      NaN    NaN   1.42
# 882        2.0         140.0            F     WO    NaN      NaN    NaN   1.27
# 885        2.0         140.0            D     WO    NaN      NaN    NaN   1.14
# 906        1.0         140.0            D     WO    NaN      NaN    NaN   1.96
# 909        1.0         160.0            F     WO    NaN      NaN    NaN   3.45
# 928        2.0         140.0            C     WO    NaN      NaN    NaN   2.93
# 933        2.0         140.0            E     WO    NaN      NaN    NaN   0.92
# 955        1.0         140.0            C     WO    NaN      NaN    NaN   3.24
# 959        2.0         140.0            B     WO    NaN      NaN    NaN   0.63
# 963        1.0         160.0            E     WO    NaN      NaN    NaN   2.88
# 994        1.0         140.0            B     WO    NaN      NaN    NaN   0.81
# 4512       2.0           0.0            9     NG    NaN     0.38    NaN    NaN
# Total      NaN           NaN          NaN    NaN   2.03     0.62    0.0  33.08

# %%
x = xx.copy()

# %%
x = x[['Forstrevier', 'Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse', 'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation', 'Bewirtschaftungsform', 'Schutzwaldkategorie', 'fl_ww', 'fl_sw', 'fl_nh', 'fl_rest']]
x = x.sort_values(['Abteilung', 'WE-Typ', 'Unterabteil.', 'Teilfl.'], ascending=[True, False, True, True])

# %%
x.columns = ['FR', 'Abt', 'Uabt', 'Tfl', 'WE-Typ',
       'BKL', 'UZ', 'NG Typ', 'Et sit',
       'BW Typ', 'SW Typ', 'fl_ww', 'fl_sw',
       'fl_nh', 'fl_rest']

# %%
x = x.fillna('-')

# %%
# make

# %%
from OBFDocX import OBFDocX
# set home directory
#home_path = os.getcwd()[:os.getcwd().find('Code/obf_autop')-1]
# set data_path
temp_path = os.path.join(os.getcwd(), 'data')
temp_path
# Out:
# '/Users/philipp/Code/obf_autop/data'

# %%
obf_doc = OBFDocX(Document(temp_path + '/templet_xx.docx'))

version = '3.8'

print('***   0 Deckblatt   ***')

obf_doc.doc.add_picture(temp_path + '/oebf.png')

for i in range(4):
    obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('OPERAT')
p.bold = True
p.font.name = 'Verdana'
p.font.size = Pt(34)

p = obf_doc.doc.add_paragraph().add_run('FB ') #+ str(obf_fuc.dic.fb) + ' ' + obf_fuc.dic.dic_num_fb[obf_fuc.dic.fb])
p.bold = True
p.font.name = 'Verdana'
p.font.size = Pt(35)

obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Teiloperat ') #+ str(obf_fuc.dic.to))
p.font.name = 'Verdana'
p.font.size = Pt(25)

for i in range(3):
    obf_doc.doc.add_paragraph('')

for i in ['Pernitz', 'Haselbach', 'Hinterbrühl']:

    p = obf_doc.doc.add_paragraph().add_run(i)
    p.font.name = 'Verdana'
    p.font.size = Pt(20)

#for i in range(12-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
#    p = obf_doc.doc.add_paragraph().add_run('')
#    p.font.size = Pt(20)

p = obf_doc.doc.add_paragraph().add_run('Organisationsstand 01.01.' + i)
p.font.name = 'Verdana'
p.font.size = Pt(18)

p = obf_doc.doc.add_paragraph().add_run('Laufzeit 01.01. - 31.12.')
p.font.name = 'Verdana'
p.font.size = Pt(18)

#for i in range(10-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
#    obf_doc.doc.add_paragraph('')

p = obf_doc.doc.add_paragraph().add_run('Für die Unternehmensleitung                       Für der Forstbetrieb')
p.font.name = 'Verdana'
p.font.size = Pt(12)

obf_doc.doc.add_page_break()

for i in range(3):
    obf_doc.doc.add_paragraph('')

run = obf_doc.doc.add_paragraph('Erstellung vom Teiloperat mit AutOP ').add_run(' Version ' + version)
font = run.font
font.name = 'Verdana'
font.size = Pt(8)

width = [2,2,2,2,2,3,2,2,2,2,2,2,2,2,2,2]
obf_doc.docx_table_text(x, width, header_rep = True, header = 'Flächenübersicht [ha]', font_size = 7, autofit = True)

# save the doc
path_save = os.path.join(temp_path, 'flaechentabelle.docx')
obf_doc.doc.save(path_save)

print('end')
print('successfully made')
# Out:
# ***   0 Deckblatt   ***
# end
# successfully made

# %%
x.shape
# Out:
# (19, 16)

# %%
x = x[['Forstrevier', 'Abteilung', 'Unterabteil.', 'Teilfl.', 'WE-Typ', 'Betriebsklasse', 'Umtriebszeit', 'Nebengrund Art', 'Ertragssituation', 'Bewirtschaftungsform', 'Schutzwaldkategorie', 'fl_ww', 'fl_sw', 'fl_nh', 'fl_rest']]
# Out:
#       Forstrevier  Abteilung Unterabteil.  Teilfl. WE-Typ  Betriebsklasse  \
# 804             1        506            A        0     WO          9010.0
# 994             1        506            B        1     WO          9010.0
# 959             1        506            B        2     WO          9010.0
# 955             1        506            C        1     WO          9010.0
# 928             1        506            C        2     WO          9010.0
# 906             1        506            D        1     WO          9010.0
# 885             1        506            D        2     WO          9010.0
# 859             1        506            D        3     WO          9010.0
# 843             1        506            D        4     WO          9010.0
# 963             1        506            E        1     WO          9050.0
# 933             1        506            E        2     WO          9010.0
# 909             1        506            F        1     WO          9050.0
# 882             1        506            F        2     WO          9010.0
# 849             1        506            G        1     WO          9010.0
# 830             1        506            G        2     WO          9010.0
# 718             1        506            3        1     NG             NaN
# 714             1        506            5        1     NG             NaN
# 710             1        506            9        1     NG             NaN
# 4512            1        506            9        2     NG             NaN
#
#       Umtriebszeit  Nebengrund Art Ertragssituation Bewirtschaftungsform  \
# 804            140             NaN                I                    W
# 994            140             NaN                I                    W
# 959            140             NaN                I                    W
# 955            140             NaN                I                    W
# 928            140             NaN                I                    W
# 906            140             NaN                I                    W
# 885            140             NaN                I                    W
# 859            140             NaN                I                    W
# 843            140             NaN                I                    W
# 963            160             NaN                I                    W
# 933            140             NaN                I                    W
# 909            160             NaN                I                    W
# 882            140             NaN                I                    W
# 849            140             NaN                I                    W
# 830            140             NaN                I                    W
# 718              0             3.0              NaN                  NaN
# 714              0             5.0              NaN                  NaN
# 710              0             9.0              NaN                  NaN
# 4512             0             9.0              NaN                  NaN
#
#       Schutzwaldkategorie  fl_ww  fl_sw  fl_nh  fl_rest
# 804                   NaN   8.69    NaN    NaN      NaN
# 994                   NaN   0.81    NaN    NaN      NaN
# 959                   NaN   0.63    NaN    NaN      NaN
# 955                   NaN   3.24    NaN    NaN      NaN
# 928                   NaN   2.93    NaN    NaN      NaN
# 906                   NaN   1.96    NaN    NaN      NaN
# 885                   NaN   1.14    NaN    NaN      NaN
# 859                   NaN   1.42    NaN    NaN      NaN
# 843                   NaN   1.39    NaN    NaN      NaN
# 963                   NaN   2.88    NaN    NaN      NaN
# 933                   NaN   0.92    NaN    NaN      NaN
# 909                   NaN   3.45    NaN    NaN      NaN
# 882                   NaN   1.27    NaN    NaN      NaN
# 849                   NaN   1.98    NaN    NaN      NaN
# 830                   NaN   0.37    NaN    NaN      NaN
# 718                   NaN    NaN    NaN   2.03      NaN
# 714                   NaN    NaN    NaN    NaN      NaN
# 710                   NaN    NaN    NaN    NaN     0.24
# 4512                  NaN    NaN    NaN    NaN     0.38

# %%
def run():
    '''
        run program
    '''
    
    obf_doc = OBFDocX(Document(temp_path + '/templet_xx.docx'))

    version = '3.8'
    
    print('***   0 Deckblatt   ***')

    obf_doc.doc.add_picture(temp_path + '/oebf.png')

    for i in range(4):
        obf_doc.doc.add_paragraph('')

    p = obf_doc.doc.add_paragraph().add_run('OPERAT')
    p.bold = True
    p.font.name = 'Verdana'
    p.font.size = Pt(34)

    p = obf_doc.doc.add_paragraph().add_run('FB ') #+ str(obf_fuc.dic.fb) + ' ' + obf_fuc.dic.dic_num_fb[obf_fuc.dic.fb])
    p.bold = True
    p.font.name = 'Verdana'
    p.font.size = Pt(35)

    obf_doc.doc.add_paragraph('')

    p = obf_doc.doc.add_paragraph().add_run('Teiloperat ') #+ str(obf_fuc.dic.to))
    p.font.name = 'Verdana'
    p.font.size = Pt(25)

    for i in range(3):
        obf_doc.doc.add_paragraph('')

    for i in obf_fuc.loop_fr()[1:]:

        p = obf_doc.doc.add_paragraph().add_run(obf_fuc.name_code(i)[1])
        p.font.name = 'Verdana'
        p.font.size = Pt(20)

    for i in range(12-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
        p = obf_doc.doc.add_paragraph().add_run('')
        p.font.size = Pt(20)

    p = obf_doc.doc.add_paragraph().add_run('Organisationsstand 01.01.' + obf_fuc.dic.laufzeit_begin)
    p.font.name = 'Verdana'
    p.font.size = Pt(18)

    p = obf_doc.doc.add_paragraph().add_run('Laufzeit 01.01.' + obf_fuc.dic.laufzeit_begin + ' - 31.12.' + obf_fuc.dic.laufzeit_end)
    p.font.name = 'Verdana'
    p.font.size = Pt(18)

    for i in range(10-(obf_fuc.loop_fr()[1:,0].shape[0]*2)):
        obf_doc.doc.add_paragraph('')

    p = obf_doc.doc.add_paragraph().add_run('Für die Unternehmensleitung                       Für der Forstbetrieb')
    p.font.name = 'Verdana'
    p.font.size = Pt(12)

    obf_doc.doc.add_page_break()

    for i in range(3):
        obf_doc.doc.add_paragraph('')

    run = obf_doc.doc.add_paragraph('Erstellung vom Teiloperat mit AutOP ').add_run(' Version ' + version)
    font = run.font
    font.name = 'Verdana'
    font.size = Pt(8)
    
    # save the doc
    path_save = os.path.join(self.data_path, 'flaechentabelle_' + str(obf_fuc.dic.to) + '.docx')
    obf_doc.doc.save(path_save)

    print('end')
    return('successfully made')
